# %% [markdown]
# # The Most Popular Programming Language Python
#
# ## Python Overview and its uses in Data Science Engineering & various Application
#
# * This is a high level computer language and It is widely used now a days and getting popular day by day.
# * It was originally developed by GUIDO-VAN-ROSSUM in 1990.
#
#     * Python 2 -> Developed in 2000
#     * Python 3 -> Developed in 2008
# ## Python Interpretor
#
# * Python is an interpreted Lanaguage.
# * Interpreter recieves a command, evaluates that command and report the results of the command.
# * Command can be saved in a plane text file known as source code or a script.
# * This script file can be saved by typing python from the command line by suffixing .py extension into that.
#     eg - if demo.py so this file called as python script file and can be executed by invoking the interprator as
#     an argument  ->python demo.py
# * Python Syntax relies on the use of white spaces.
# * Individual statements are typically concluded with a new line charachter.
#     Although a command can extent to another line either with a concluding back slash (\) or opening curly braces {}.
#
# NOTE -> Whitespaces is a key in delimiting the bodies of control structure in python.So Amounts of interaction is very much important while writting nested control structures and all.
#
# ** Python enables programs to be written compactly and readably. Programs written in Python are typically much shorter than equivalent C, C++, or Java programs, for several reasons:
#
# <li> the high-level data types allow you to express complex operations in a single statement;
#
# <li> statement grouping is done by indentation instead of beginning and ending brackets;
#
# <li> no variable or argument declarations are necessary.
#
# *** Now we will see and learn along with you python script.
#
# **** https://docs.python.org/3/tutorial/introduction.html

# %%
###
from IPython.display import Image
Image(filename='F:\AiML\Python\python architechture.png')

# %% [markdown]
# ## Identifiers, Objects, and the Assignment Statement
#
#     temperature = 98.6
# * This command establishes temperature as an <i> identifier</i>
# * The floating value 98.6 as a data type object expressed with its value 98.6
#
# * Identifiers in Python are case-sensitive, so temperature and Temperature are distinct
# names.

# %%
###
from IPython.display import Image
Image(filename='F:\AiML\Python\Reserved words in Python.JPG')
